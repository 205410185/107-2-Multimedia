# %% [markdown]
# <a href="https://colab.research.google.com/github/VongolaXIman/107-2-Multimedia/blob/master/Class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

#主函數
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imgToArray.py imageFile")
  plt.imshow(image,cmap='gray')#https://blog.csdn.net/lanchunhui/article/details/66972783
  plt.show()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
image2 = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg', cv2.IMREAD_COLOR)#default
# plt.imshow(image2)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image3 = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg', cv2.IMREAD_UNCHANGED)#including alpha channel
plt.imshow(cv2.cvtColor(image3,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg', 0)# -1 0 1 2 3 4....................
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[200, 195, 213, ..., 231, 234, 234],
#        [208, 210, 214, ..., 225, 227, 223],
#        [213, 216, 212, ..., 228, 231, 225],
#        ...,
#        [186, 185, 179, ...,  26,  28,  28],
#        [197, 187, 174, ...,  29,  27,  18],
#        [182, 171, 168, ...,  25,  27,  16]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/107-2Multimedia/k.jpg')
b,g,r = cv2.split(image6)#slow
img = cv2.merge((r,g,b))#slow
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
